# %% [markdown]
# <a href="https://www.kaggle.com/code/josephmclauchlan/games-missed-in-nhl-2012-2023?scriptVersionId=122308131" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
# Path of the file to read
nhl_filepath = "/kaggle/input/nhl-concussion-data-2012-2023/dataset/NHL Concussions Database_data.csv"

# Read the file into a variable nhl_data
nhl_data = pd.read_csv(nhl_filepath, index_col="Season")

# %%
# Print the first 5 rows of the data
nhl_data.head()

# %%
list(nhl_data.columns)

# %%
# Set the width and height of the figure
plt.figure(figsize=(50,20))

# Add title
plt.title("NHL Games missed Due to Concussion in 2012-2023")

# Line chart 
sns.lineplot(data=nhl_data['Games Missed'], label="Games Missed")

# Add label for horizontal axis
plt.xlabel("Season")
